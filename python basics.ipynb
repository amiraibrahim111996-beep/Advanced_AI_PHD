# %%
# Variables and data types
name = "Amira"
age = 30
salary = 5000.50
is_student = False

print("Name:", name)
print("Age:", age)
print("Salary:", salary)
print("Student:", is_student)
# Out:
# Name: Amira
# Age: 30
# Salary: 5000.5
# Student: False

# %%
# Conditional statements
if age >= 20:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
# Loops
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Lists
numbers = [10, 20, 30, 40]
print("\nList of numbers:", numbers)
numbers.append(50)
print("After adding 50:", numbers)
# Out:
# List of numbers: [10, 20, 30, 40]
# After adding 50: [10, 20, 30, 40, 50]

# %%
# Functions
def display():
    return f"Hello,! Welcome to Python basics."

print("\n", display())
# Out:
#  Hello,! Welcome to Python basics.

# %%
# Object-Oriented Programming

#  Class and Constructor
class Person:
    def __init__(self, name, age):
        self.name = name      # attribute
        self.age = age        # attribute

    def display_info(self):   # method
        print(f"Name: {self.name}, Age: {self.age}")

# Create object from Person class
person1 = Person("Amira", 25)
person1.display_info()
# Out:
# Name: Amira, Age: 25

# %%
# Inheritance

class Employee(Person):  # Employee inherits from Person
    def __init__(self, name, age, salary):
        # Call the parent constructor using super()
        super().__init__(name, age)
        self.salary = salary

    def display_employee(self):
        print(f"Name: {self.name}, Age: {self.age}, Salary: {self.salary}")

# Create object from Employee 
employee1 = Employee("Sara", 30, 7500)
employee1.display_employee()
# Out:
# Name: Sara, Age: 30, Salary: 7500
